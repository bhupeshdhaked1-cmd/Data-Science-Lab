# %% [markdown]
# #tuple
# ## orderd of collection of items
# ## symblo()
# ##tuple immutable

# %%
# create a tuple
student=(101,"chirag","cse",8.9)
print(student)
#Access by index
print("student Department:",student[2])
#access by negative index
print("Accessing by negative index:",student[-2])
# Out:
# (101, 'chirag', 'cse', 8.9)
# student Department: cse
# Accessing by negative index: cse

# %%
subjects=("DSV","Mechine L","OS","Cloude","SQL","Statistics", "Python")
print(subjects)
print("length of the tuple is:",len(subjects))
# Out:
# ('DSV', 'Mechine L', 'OS', 'Cloude', 'SQL', 'Statistics', 'Python')
# length of the tuple is: 7

# %%
#tuple slicing
print(subjects[3:])
print(subjects[1:5])
# Out:
# ('Cloude', 'SQL', 'Statistics', 'Python')
# ('Mechine L', 'OS', 'Cloude', 'SQL')

# %%
#tuple is mutuble or immutable
print(student)
student[1]="Manish"
print(student)
# Out:
# (101, 'chirag', 'cse', 8.9)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_999/3180333351.py in <cell line: 0>()
#       1 #tuple is mutuble or immutable
#       2 print(student)
# ----> 3 student[1]="Manish"
#       4 print(student)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Nested tuple
student_info =(1005,"Rahul",(89,98,78,75))
print(student_info)
print("Nested tuple display 3rd subject mark:",student_info[2][2])
# Out:
# (1005, 'Rahul', (89, 98, 78, 75))
# Nested tuple display 3rd subject mark: 78

# %%
position=student_info.index("Rahul")
print("Data Rahul present in the index", position)
# Out:
# Data Rahul present in the index 1

# %% [markdown]
# #set
#  ## unorderd collection of items
#  ## mutuble
#  {}
#  ## no duplication
#  ## it will give the unique values
#  ## union , intersection,difference , symmetric differece, superset

# %%
#create a set
subject_info={"Data Science and visualization",
              "SQL",
              "Statistics",
              "Machine Learning"}
print(subject_info)
# Out:
# {'Machine Learning', 'Data Science and visualization', 'Statistics', 'SQL'}

# %%
studentname={"Amit","Sanjiv","Kalai","Amit","Kajal","Neha"}
print(studentname)
# Out:
# {'Kajal', 'Sanjiv', 'Kalai', 'Amit', 'Neha'}

# %%
print(studentsname[2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_999/3522708508.py in <cell line: 0>()
# ----> 1 print(studentsname[2])
#
# NameError: name 'studentsname' is not defined

# %%
#adding an element in the set
studentname.add("priya")
print(studentname)
#update the set
studentname.update(["Anil","Nandhini","Balaji"])
print(studentname)
#remove an item
studentname.remove("priya")
print(studentname)
# Out:
# {'Balaji', 'Kalai', 'Amit', 'Kajal', 'priya', 'Nandhini', 'Neha', 'Anil', 'Sanjiv'}
# {'Balaji', 'Kalai', 'Amit', 'Kajal', 'priya', 'Nandhini', 'Neha', 'Anil', 'Sanjiv'}
# {'Balaji', 'Kalai', 'Amit', 'Kajal', 'Nandhini', 'Neha', 'Anil', 'Sanjiv'}

# %%
#clean an delete
number={89,78,68,97,69}
number.clear()
print(number)


del number
print(number)
# Out:
# set()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_999/738325357.py in <cell line: 0>()
#       6
#       7 del number
# ----> 8 print(number)
#
# NameError: name 'number' is not defined

# %%
#find the element in the set
print(studentname)
#find  the element Anil
print("Anil" in studentname)
# Out:
# {'Balaji', 'Kalai', 'Amit', 'Kajal', 'Nandhini', 'Neha', 'Anil', 'Sanjiv'}
# True

# %%
#set operation
#union
#intersection
#different
#symeetric difference


python_students={"rahul","priya","hari","ganesh"}
java_student={"rahul","haro","kiran","ravi","giri"}
res_union=python_students.union(java_student)
print(res_union)
res_diff=python_students.difference(java_student)
print(res_diff)
# Out:
# {'priya', 'ravi', 'giri', 'ganesh', 'kiran', 'rahul', 'haro', 'hari'}
# {'priya', 'hari', 'ganesh'}
